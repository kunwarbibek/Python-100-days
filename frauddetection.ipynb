# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split  
dataset=pd.read_csv(r"D:\MML\fraud detection\creditcard.csv")
dataset.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
dataset.shape
# Out:
# (284807, 31)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
dataset.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
 dataset.duplicated().sum()
# Out:
# np.int64(1081)

# %%
dataset.drop_duplicates(inplace=True)

# %%
dataset.shape
# Out:
# (283726, 31)

# %%
dataset.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
dataset['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
dataset['Class'].value_counts(normalize=True) * 100
# Out:
# Class
# 0    99.83329
# 1     0.16671
# Name: proportion, dtype: float64

# %%
legitimate = dataset[dataset['Class'] == 0]
fraud = dataset[dataset['Class'] == 1]
legitimate.shape
# Out:
# (283253, 31)

# %%
fraud.shape
# Out:
# (473, 31)

# %%
legitimate['Amount'].describe()
# Out:
# count    283253.000000
# mean         88.413575
# std         250.379023
# min           0.000000
# 25%           5.670000
# 50%          22.000000
# 75%          77.460000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud['Amount'].describe()
# Out:
# count     473.000000
# mean      123.871860
# std       260.211041
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94835.058093  0.013439 -0.009829  0.012853 -0.010440  0.006769
# 1      80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
#
#              V6        V7        V8        V9  ...       V20      V21  \
# Class                                          ...
# 0      0.001251  0.010447 -0.002448  0.002613  ... -0.000489 -0.00115
# 1     -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.46655
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000160  0.000360  0.000393 -0.000301  0.000065  0.001409  0.000418
# 1      0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
#
#            Amount
# Class
# 0       88.413575
# 1      123.871860
#
# [2 rows x 30 columns]

# %%
legitimate_sample=legitimate.sample(n=473)
legitimate_sample.head(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 275366  166497.0  2.069706 -0.950600 -0.421088 -0.517611 -1.061008 -0.270327
# 95928    65531.0 -0.275338  0.973317  1.336548  0.485929  0.204261 -0.955948
# 34861    37856.0 -0.504457  0.252410  1.270499 -2.328149  0.344970  0.340611
# 193251  130058.0  1.970262 -1.239786 -0.505245 -0.935140 -1.111739 -0.294501
# 38233    39305.0  0.860659 -0.514277  1.151125  1.132799 -1.097562  0.216735
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 275366 -0.974688  0.059705 -0.196346  ... -0.591490 -1.216312  0.466770
# 95928   0.603334 -0.152652 -0.664599  ... -0.143584 -0.420306  0.063512
# 34861   0.297196  0.145296 -1.619103  ... -0.144398 -0.712355 -0.338415
# 193251 -1.007583 -0.053879 -0.274633  ...  0.493890  1.295593 -0.006678
# 38233  -0.702654  0.387771  0.559288  ...  0.259388  0.442888 -0.048738
#
# ...

# %%
fraud.head(5)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset = pd.concat([legitimate_sample, fraud], axis=0)
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 275366  166497.0  2.069706 -0.950600 -0.421088 -0.517611 -1.061008 -0.270327
# 95928    65531.0 -0.275338  0.973317  1.336548  0.485929  0.204261 -0.955948
# 34861    37856.0 -0.504457  0.252410  1.270499 -2.328149  0.344970  0.340611
# 193251  130058.0  1.970262 -1.239786 -0.505245 -0.935140 -1.111739 -0.294501
# 38233    39305.0  0.860659 -0.514277  1.151125  1.132799 -1.097562  0.216735
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 275366 -0.974688  0.059705 -0.196346  ... -0.591490 -1.216312  0.466770
# 95928   0.603334 -0.152652 -0.664599  ... -0.143584 -0.420306  0.063512
# 34861   0.297196  0.145296 -1.619103  ... -0.144398 -0.712355 -0.338415
# 193251 -1.007583 -0.053879 -0.274633  ...  0.493890  1.295593 -0.006678
# 38233  -0.702654  0.387771  0.559288  ...  0.259388  0.442888 -0.048738
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      98358.784355  0.018393 -0.074468 -0.068330  0.019381  0.062018
# 1      80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.024195  0.004718  0.066785 -0.028919  ...  0.032186  0.052083
# 1     -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.466550
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.018460  0.058898 -0.006140 -0.016452  0.006249  0.008926 -0.012423
# 1      0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
#
#            Amount
# Class
# 0       91.211564
# 1      123.871860
#
# [2 rows x 30 columns]

# %%
# splitting the data 
x=new_dataset.drop(columns=('Class'), axis=1)
x.head(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 275366  166497.0  2.069706 -0.950600 -0.421088 -0.517611 -1.061008 -0.270327
# 95928    65531.0 -0.275338  0.973317  1.336548  0.485929  0.204261 -0.955948
# 34861    37856.0 -0.504457  0.252410  1.270499 -2.328149  0.344970  0.340611
# 193251  130058.0  1.970262 -1.239786 -0.505245 -0.935140 -1.111739 -0.294501
# 38233    39305.0  0.860659 -0.514277  1.151125  1.132799 -1.097562  0.216735
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 275366 -0.974688  0.059705 -0.196346  ... -0.579243 -0.591490 -1.216312
# 95928   0.603334 -0.152652 -0.664599  ...  0.111201 -0.143584 -0.420306
# 34861   0.297196  0.145296 -1.619103  ...  0.159658 -0.144398 -0.712355
# 193251 -1.007583 -0.053879 -0.274633  ...  0.244912  0.493890  1.295593
# 38233  -0.702654  0.387771  0.559288  ... -0.039528  0.259388  0.442888
#
# ...

# %%
y=new_dataset['Class']
y.head(5)
# Out:
# 275366    0
# 95928     0
# 34861     0
# 193251    0
# 38233     0
# Name: Class, dtype: int64

# %%
#split data into test and train 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (946, 30) (756, 30) (190, 30)

# %%
# train model using loastic regression
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_predict = lr.predict(x_train)
lr_acc = accuracy_score(y_train, x_predict)
print("Training Accuracy:", lr_acc)

test_acc = accuracy_score(y_test, lr.predict(x_test))
print("Test Accuracy:", test_acc)
# Out:
# Training Accuracy: 0.9404761904761905
# Test Accuracy: 0.9421052631578948

# %%
sample_data =  [[0,-1.3598071336738,-0.0727811733098497,2.53634673796914,1.37815522427443,
         -0.338320769942518,0.462387777762292,0.239598554061257,0.0986979012610507,
         0.363786969611213,0.0907941719789316,-0.551599533260813,-0.617800855762348,
         -0.991389847235408,-0.311169353699879,1.46817697209427,-0.470400525259478,
         0.207971241929242,0.0257905801985591,0.403992960255733,0.251412098239705,
         -0.018306777944153,0.277837575558899,-0.110473910188767,0.0669280749146731,
         0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,
         149.62]]
transaction_df = pd.DataFrame(transaction_data, columns=x_train.columns)
prediction = lr.predict(transaction_df)
print("Prediction:", prediction[0])
# Out:
# Prediction: 0
